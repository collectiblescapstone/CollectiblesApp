# %% [markdown]
# # YOlO experimentation
#
# This notebook provides the code to create training data, and train the ultralytics YOLO model to produce oriented bounding boxes (OBB) around pokemon cards in an image.

# %% [markdown]
# ### notes
#
# ONNX format - potential increased execution speed, can be used by many libraries https://docs.ultralytics.com/integrations/onnx/
#
#
# possible dataset improvements
#
# - cut out random shapes from around the edge
# - glare that extends beyond the card
# - colored rectangles around card to emulate sleeves
# - tight grids to simulate binders
# - higher frequency of full art/full card designs
# - incomplete cards that clip off screen

# %% [markdown]
# ### setup

# %%
# !pip install ultralytics "onnx>=1.12.0,<2.0.0" "onnxslim>=0.1.71" onnxruntime-gpu
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ultralytics in c:\users\rsninja\appdata\roaming\python\python310\site-packages (8.4.7)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\rsninja\appdata\roaming\python\python310\site-packages (from ultralytics) (2.2.6)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\program files\python310\lib\site-packages (from ultralytics) (3.10.1)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\rsninja\appdata\roaming\python\python310\site-packages (from ultralytics) (4.9.0.80)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\rsninja\appdata\roaming\python\python310\site-packages (from ultralytics) (11.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\rsninja\appdata\roaming\python\python310\site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in c:\users\rsninja\appdata\roaming\python\python310\site-packages (from ultralytics) (2.32.5)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\rsninja\appdata\roaming\python\python310\site-packages (from ultralytics) (1.15.2)
# Requirement already satisfied: torch<2.10,>=1.8.0 in c:\users\rsninja\appdata\roaming\python\python310\site-packages (from ultralytics) (2.9.0)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\rsninja\appdata\roaming\python\python310\site-packages (from ultralytics) (0.24.0)
# Requirement already satisfied: psutil>=5.8.0 in c:\users\rsninja\appdata\roaming\python\python310\site-packages (from ultralytics) (6.1.1)
# Requirement already satisfied: polars>=0.20.0 in c:\users\rsninja\appdata\roaming\python\python310\site-packages (from ultralytics) (1.37.1)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in c:\users\rsninja\appdata\roaming\python\python310\site-packages (from ultralytics) (2.0.18)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rsninja\appdata\roaming\python\python310\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\rsninja\appdata\roaming\python\python310\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rsninja\appdata\roaming\python\python310\site-packages (from matplotlib>=3.3.0->ultralytics) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\rsninja\appdata\roaming\python\python310\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\rsninja\appdata\roaming\python\python310\site-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\rsninja\appdata\roaming\python\python310\site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rsninja\appdata\roaming\python\python310\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.37.1 in c:\users\rsninja\appdata\roaming\python\python310\site-packages (from polars>=0.20.0->ultralytics) (1.37.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\rsninja\appdata\roaming\python\python310\site-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rsninja\appdata\roaming\python\python310\site-packages (from requests>=2.23.0->ultralytics) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rsninja\appdata\roaming\python\python310\site-packages (from requests>=2.23.0->ultralytics) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rsninja\appdata\roaming\python\python310\site-packages (from requests>=2.23.0->ultralytics) (2025.4.26)
# Requirement already satisfied: filelock in c:\users\rsninja\appdata\roaming\python\python310\site-packages (from torch<2.10,>=1.8.0->ultralytics) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\rsninja\appdata\roaming\python\python310\site-packages (from torch<2.10,>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\rsninja\appdata\roaming\python\python310\site-packages (from torch<2.10,>=1.8.0->ultralytics) (1.13.3)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\rsninja\appdata\roaming\python\python310\site-packages (from torch<2.10,>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\rsninja\appdata\roaming\python\python310\site-packages (from torch<2.10,>=1.8.0->ultralytics) (3.1.5)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\rsninja\appdata\roaming\python\python310\site-packages (from torch<2.10,>=1.8.0->ultralytics) (2025.9.0)
# Requirement already satisfied: six>=1.5 in c:\users\rsninja\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\rsninja\appdata\roaming\python\python310\site-packages (from sympy>=1.13.3->torch<2.10,>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\rsninja\appdata\roaming\python\python310\site-packages (from jinja2->torch<2.10,>=1.8.0->ultralytics) (3.0.2)
# [notice] A new release of pip is available: 25.0 -> 25.3
# [notice] To update, run: C:\Program Files\Python310\python.exe -m pip install --upgrade pip

# %%
# imports
import os
import random
import zipfile
import urllib
import math
from ultralytics import YOLO
from PIL import Image, ImageStat, ImageEnhance, ImageDraw, ImageFilter
import tqdm
import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# %% [markdown]
# # Dataset creation

# %%
# configure dataset settings here

DATASET_PATH = "../datasets/YOLO_training"
OBJECTS_PATH = "../datasets/pokemon/data/images" # the objects you want the model to detect
OBJECTS_HEIGHT = 825
OBJECTS_WIDTH = 600
OBJECTS_ASPECT_RATIO = OBJECTS_HEIGHT / OBJECTS_WIDTH
IMAGE_DIMENSION = 640

# dataset generation settings
AMOUNT_TRAIN = 250
AMOUNT_VAL = 0
MAX_CARDS_PER_IMAGE = 9
ALLOW_OVERLAP = False
BLACK_AND_WHITE = False
OBSTRUCTIONS = True

# training settings
EPOCHS = 100

# %% [markdown]
# ### download images to use as backgrounds

# %%
url = "http://images.cocodataset.org/zips/val2017.zip"
output_path = DATASET_PATH + "/backgrounds/val2017.zip" 

# create directory
if not os.path.exists(os.path.dirname(output_path)):
    os.makedirs(os.path.dirname(output_path), exist_ok=True)

if not os.path.exists(DATASET_PATH + "/backgrounds/val2017/"):
    # download and extract
    print("Downloading background images...")
    urllib.request.urlretrieve(url, output_path)
    print("Extracting")
    with zipfile.ZipFile(output_path, 'r') as zip_ref:
        zip_ref.extractall(DATASET_PATH + "/backgrounds/")

    # cleanup
    os.remove(output_path)
print("Background images ready.")
# Out:
# Background images ready.

# %% [markdown]
# ### Remove empty directories from objects path
#
# this is done since we select random directories to find random images, and this breaks if empty directories exist

# %%
# remove all empty directories in OBJECTS_PATH
for dirpath, dirnames, filenames in os.walk(OBJECTS_PATH, topdown=False):
    if not dirnames and not filenames:
        os.rmdir(dirpath)

# %% [markdown]
# ### Utility functions

# %%
def load_random_background() -> str:
    bg_path = DATASET_PATH + "/backgrounds/val2017/"
    bg_image = random.choice(os.listdir(bg_path))
    return bg_path + bg_image

mandatory_cards = [
    "../datasets/pokemon/data/images/xy12/xy12-100.jpg",
    "../datasets/pokemon/data/images/xy12/xy12-103.jpg",
    "../datasets/pokemon/data/images/xy12/xy12-106.jpg",
    "../datasets/pokemon/data/images/xy12/xy12-107.jpg",
    "../datasets/pokemon/data/images/xy12/xy12-108.jpg",
    "../datasets/pokemon/data/images/xy12/xy12-93.jpg",
    "../datasets/pokemon/data/images/xy12/xy12-95.jpg",
    "../datasets/pokemon/data/images/xy12/xy12-65.jpg",
    "../datasets/pokemon/data/images/xy7/xy7-98.jpg",
    "../datasets/pokemon/data/images/xy7/xy7-86.jpg",
    "../datasets/pokemon/data/images/xy7/xy7-37.jpg",
    "../datasets/pokemon/data/images/xy7/xy7-21.jpg",
    "../datasets/pokemon/data/images/xy7/xy7-32.jpg",
    "../datasets/pokemon/data/images/swsh12/swsh12-171.jpg",
    "../datasets/pokemon/data/images/swsh12/swsh12-176.jpg",
    "../datasets/pokemon/data/images/swsh12/swsh12-204.jpg",
    "../datasets/pokemon/data/images/swsh12/swsh12-215.jpg",
    "../datasets/pokemon/data/images/swsh12/swsh12-200.jpg",
    "../datasets/pokemon/data/images/swsh12/swsh12-TG19.jpg",
    "../datasets/pokemon/data/images/swsh12/swsh12-TG30.jpg",
    "../datasets/pokemon/data/images/swsh12/swsh12-TG28.jpg",
    "../datasets/pokemon/data/images/swsh12/swsh12-177.jpg",
    "../datasets/pokemon/data/images/swsh12/swsh12-211.jpg",
    "../datasets/pokemon/data/images/swsh12/swsh12-065.jpg",
    "../datasets/pokemon/data/images/swsh12/swsh12-024.jpg",
    "../datasets/pokemon/data/images/swsh6/swsh6-113.jpg",
    "../datasets/pokemon/data/images/swsh6/swsh6-104.jpg",
    "../datasets/pokemon/data/images/swsh6/swsh6-164.jpg",
    "../datasets/pokemon/data/images/swsh6/swsh6-305.jpg",
    "../datasets/pokemon/data/images/swsh6/swsh6-233.jpg",
    "../datasets/pokemon/data/images/swsh6/swsh6-230.jpg",
    "../datasets/pokemon/data/images/swsh6/swsh6-201.jpg",
    "../datasets/pokemon/data/images/swsh6/swsh6-209.jpg",
    "../datasets/pokemon/data/images/svp/svp-195.jpg",
    "../datasets/pokemon/data/images/svp/svp-163.jpg",
    "../datasets/pokemon/data/images/svp/svp-166.jpg",
    "../datasets/pokemon/data/images/svp/svp-165.jpg",
    "../datasets/pokemon/data/images/svp/svp-163.jpg",
    "../datasets/pokemon/data/images/svp/svp-132.jpg",
    "../datasets/pokemon/data/images/svp/svp-129.jpg",
    "../datasets/pokemon/data/images/svp/svp-083.jpg",
    "../datasets/pokemon/data/images/svp/svp-084.jpg",
    "../datasets/pokemon/data/images/svp/svp-081.jpg",
    "../datasets/pokemon/data/images/svp/svp-053.jpg",
    "../datasets/pokemon/data/images/svp/svp-053.jpg",
    "../datasets/pokemon/data/images/sv03.5/sv03.5-186.jpg",
    "../datasets/pokemon/data/images/sv03.5/sv03.5-190.jpg",
    "../datasets/pokemon/data/images/sv03.5/sv03.5-194.jpg",
    "../datasets/pokemon/data/images/sv03.5/sv03.5-205.jpg",
    "../datasets/pokemon/data/images/sv03.5/sv03.5-145.jpg",
    "../datasets/pokemon/data/images/sv03.5/sv03.5-038.jpg",
    "../datasets/pokemon/data/images/me01/me01-100.jpg",
    "../datasets/pokemon/data/images/me01/me01-133.jpg",
    "../datasets/pokemon/data/images/me01/me01-156.jpg",
    "../datasets/pokemon/data/images/me01/me01-163.jpg",
    "../datasets/pokemon/data/images/me01/me01-168.jpg",
    "../datasets/pokemon/data/images/me01/me01-173.jpg",
    "../datasets/pokemon/data/images/me01/me01-180.jpg",
    "../datasets/pokemon/data/images/me01/me01-185.jpg",
    "../datasets/pokemon/data/images/me01/me01-187.jpg"
]

mandatory_index = 0

def reset_index():
    global mandatory_index
    mandatory_index = 0

def load_random_card() -> str:
    global mandatory_index
    if mandatory_index < len(mandatory_cards):
        card = mandatory_cards[mandatory_index]
        mandatory_index += 1
        return card

    # images may be in subdirectories
    path = random.choice(os.listdir(OBJECTS_PATH))
    while os.path.isdir(os.path.join(OBJECTS_PATH, path)):
        path = os.path.join(path, random.choice(os.listdir(os.path.join(OBJECTS_PATH, path))))
        # check if directory is empty
        if os.path.isdir(path) and len(os.listdir(path)) == 0:
            # return the first card that is downloaded in case all of the cards haven't been downloaded yet
            return "../datasets/pokemon/data/images/base1/base1-1.jpg"
    return os.path.join(OBJECTS_PATH, path)

def normalize_homography(H):
    """Normalize so H[2,2] == 1"""
    return H / H[2, 2]

def compose(*matrices):
    """
    Compose transforms left → right.
    compose(A, B, C) means: C @ B @ A
    """
    H = np.eye(3)
    for M in matrices:
        H = M @ H
    return normalize_homography(H)

def translate(tx, ty):
    return np.array([
        [1, 0, tx],
        [0, 1, ty],
        [0, 0, 1]
    ], dtype=float)


def rotate(theta_rad, center=None):
    c, s = math.cos(theta_rad), math.sin(theta_rad)
    R = np.array([
        [ c, -s, 0],
        [ s,  c, 0],
        [ 0,  0, 1]
    ], dtype=float)

    if center is None:
        return R

    cx, cy = center
    return compose(
        translate(-cx, -cy),
        R,
        translate(cx, cy)
    )

def perspective_from_corners(src_pts, dst_pts):
    """
    src_pts, dst_pts: lists of 4 (x, y) pairs
    Order must be consistent (e.g. TL, TR, BR, BL)
    """
    A = []
    b = []

    for (x, y), (u, v) in zip(src_pts, dst_pts):
        A.append([x, y, 1, 0, 0, 0, -u*x, -u*y])
        A.append([0, 0, 0, x, y, 1, -v*x, -v*y])
        b.append(u)
        b.append(v)

    A = np.array(A, dtype=float)
    b = np.array(b, dtype=float)

    h = np.linalg.solve(A, b)

    H = np.array([
        [h[0], h[1], h[2]],
        [h[3], h[4], h[5]],
        [h[6], h[7], 1.0]
    ])

    return normalize_homography(H)

def to_pillow_perspective(H):
    """
    Convert 3x3 homography to Pillow's 8-tuple
    """
    H = normalize_homography(H)
    return (
        H[0,0], H[0,1], H[0,2],
        H[1,0], H[1,1], H[1,2],
        H[2,0], H[2,1],
    )

def get_corners_after_transform(start_w, start_h, H: np.ndarray) -> list:
    corners = [
        (0, 0),
        (start_w, 0),
        (start_w, start_h),
        (0, start_h)
    ]
    transformed_corners = []
    for x, y in corners:
        vec = np.array([x, y, 1], dtype=float)
        tx, ty, tz = H @ vec
        transformed_corners.append((float(tx / tz), float(ty / tz)))
    return transformed_corners

def mesh_distort(img: Image.Image) -> Image.Image:
    np_img = np.array(img)
    rgb = np_img[..., :3]
    alpha = np_img[..., 3]

    cv_rgb = cv2.cvtColor(rgb, cv2.COLOR_RGBA2RGB)
    h, w = cv_rgb.shape[:2]

    focal_length = w
    camera_matrix = np.array([
        [focal_length, 0, w / 2],
        [0, focal_length, h / 2],
        [0, 0, 1]
    ], dtype="float32")

    randodist_coeffs = np.array([
        random.uniform(-0.05, 0.05),   # k1
        random.uniform(-0.02, 0.02),   # k2
        random.uniform(-0.005, 0.005), # p1
        random.uniform(-0.005, 0.005), # p2
        random.uniform(-0.01, 0.01)    # k3
    ], dtype=np.float32)

    new_camera_mtx, _ = cv2.getOptimalNewCameraMatrix(
        camera_matrix,
        randodist_coeffs,
        (w, h),
        alpha=0
    )

    map1, map2 = cv2.initUndistortRectifyMap(
        camera_matrix,
        randodist_coeffs,
        None,
        new_camera_mtx,
        (w, h),
        cv2.CV_32FC1
    )

    distorted_rgb = cv2.remap(
        cv_rgb,
        map1,
        map2,
        interpolation=cv2.INTER_LINEAR,
        borderMode=cv2.BORDER_CONSTANT,
        borderValue=(0, 0, 0)
    )

    distorted_alpha = cv2.remap(
        alpha,
        map1,
        map2,
        interpolation=cv2.INTER_LINEAR,
        borderMode=cv2.BORDER_CONSTANT,
        borderValue=0
    )

    # Stack channels
    rgba = np.dstack([distorted_rgb, distorted_alpha])

    # find border pixels (non-zero pixels beside zero pixels or edge of image)
    border_mask = np.zeros((h, w), dtype=bool)
    for y in range(h):
        for x in range(w):
            if distorted_alpha[y, x] == 0:
                continue
            if (x == 0 or distorted_alpha[y, x-1] == 0) or \
               (x == w-1 or distorted_alpha[y, x+1] == 0) or \
               (y == 0 or distorted_alpha[y-1, x] == 0) or \
               (y == h-1 or distorted_alpha[y+1, x] == 0):
                border_mask[y, x] = True
    
    # expand mask to neighboring pixels to ensure no gaps
    kernel = np.ones((3, 3), dtype=np.uint8)
    expanded_mask = cv2.dilate(border_mask.astype(np.uint8), kernel, iterations=1).astype(bool)
    # set border pixels half transparent to create a smoother transition
    distorted_alpha[expanded_mask] = np.minimum(distorted_alpha[expanded_mask], 128)
    # update the distorted image with the new alpha values
    rgba[..., 3] = distorted_alpha

    # create final image with smoothed borders
    distorted_pil = Image.fromarray(rgba, mode="RGBA")

    # apply blur to entire image
    distorted_pil = distorted_pil.filter(ImageFilter.GaussianBlur(radius=random.uniform(0.5, 1)))

    return distorted_pil

# %% [markdown]
# ### Images creation

# %%
def create_test_item(only_1=False):
    shapes = []

    # smaller cards if more cards per image
    card_amount = 1 if only_1 else random.randint(1, MAX_CARDS_PER_IMAGE)
    if card_amount == 5 or card_amount == 7:
        card_amount = 4
    x = IMAGE_DIMENSION / math.ceil(math.sqrt(card_amount))
    # assuming a card is rotated so its diagonal is aligned with the grid, what is the max height so the card still fits
    max_card_size = math.floor((x * (OBJECTS_HEIGHT if OBJECTS_HEIGHT > OBJECTS_WIDTH else OBJECTS_WIDTH)) / (math.sqrt(OBJECTS_HEIGHT**2 + OBJECTS_WIDTH**2)))

    # use python image library to paste cards onto background
    
    # load background 
    bg_image_path = load_random_background()
    bg_image = Image.open(bg_image_path).convert("RGB")
    if BLACK_AND_WHITE:
        bg_image = bg_image.convert("L").convert("RGB")
    bg_image = bg_image.resize((IMAGE_DIMENSION, IMAGE_DIMENSION))

    # calculate average brightness of background
    bg_image_gray = bg_image.convert("L")
    stat = ImageStat.Stat(bg_image_gray)
    bg_brightness = stat.mean[0]

    # calculate image white balance
    # stat = ImageStat.Stat(bg_image)
    # r_avg, g_avg, b_avg = stat.mean
    # gray_avg = (r_avg + g_avg + b_avg) / 3
    # r_ratio = gray_avg / (r_avg + 1e-5)
    # g_ratio = gray_avg / (g_avg + 1e-5)
    # b_ratio = gray_avg / (b_avg + 1e-5)
    # # bound between 0.5 and 2 to avoid extreme color shifts
    # r_ratio = max(min(r_ratio, 2), 0.5)
    # g_ratio = max(min(g_ratio, 2), 0.5)
    # b_ratio = max(min(b_ratio, 2), 0.5)

    # paste cards
    for i in range(card_amount):
        card_height = random.uniform(150, max_card_size)
        # load card
        card_image_path = load_random_card()
        try:
            card_image = Image.open(card_image_path).convert("RGBA")
        except:
            continue
        if BLACK_AND_WHITE:
            card_image = card_image.convert("L").convert("RGBA")
        card_image = card_image.resize((int(card_height / OBJECTS_ASPECT_RATIO), int(card_height)))

        # apply obstruction if enabled
        if OBSTRUCTIONS and random.random() < 0.33:
            draw = Image.new('RGBA', card_image.size, (0, 0, 0, 0))
            obstruction_amount = random.randint(1, 7)

            # generate random shapes of varying size, shape, brightness, and alpha
            for _ in range(obstruction_amount):
                obs_w = random.randint(int(card_image.width * 0.1), int(card_image.width * 0.6))
                obs_h = random.randint(int(card_image.height * (0.4 if obs_w < card_image.width * 0.3 else 0.1)), int(card_image.height * (0.6 if obs_w < card_image.width * 0.3 else 0.2)))
                obs_x = random.randint(0, card_image.width - obs_w)
                obs_y = random.randint(0, card_image.height - obs_h)
                base_alpha = random.randint(150, 215)
                obstruction = Image.new('RGBA', (obs_w, obs_h), (0,0,0,0))
                ImageDraw.Draw(obstruction,mode='RGBA').ellipse([(0, 0), (obs_w, obs_h)], fill=(255,255,255, base_alpha), outline=None)
                # remove random shapes from obstruction to make it less blocky
                mask = Image.new('L', (obs_w, obs_h), 255)
                for _ in range(random.randint(0, 2)):
                    shape_w = random.randint(int(obs_w * 0.1), int(obs_w * 0.7))
                    shape_h = random.randint(int(obs_h * 0.1), int(obs_h * 0.7))
                    shape_x = random.randint(int(-obs_w/3), int(obs_w + obs_w/3))
                    shape_y = random.randint(int(-obs_h/3), int(obs_h + obs_h/3))
                    shape_x = int(max(min(shape_x, obs_w - shape_w), 0))
                    shape_y = int(max(min(shape_y, obs_h - shape_h), 0))
                    shape = Image.new('L', (shape_w, shape_h), 0)
                    mask.paste(shape, (shape_x, shape_y))
                current_alpha = np.array(obstruction.getchannel('A'), dtype=np.uint16)
                cutout_mask = np.array(mask, dtype=np.uint16)
                combined_alpha = ((current_alpha * cutout_mask) // 255).astype(np.uint8)
                obstruction.putalpha(Image.fromarray(combined_alpha, mode='L'))
                # blur obstruction to make it less sharp
                obstruction = obstruction.filter(ImageFilter.GaussianBlur(radius=3))
                
                rot = random.uniform(0, 360)
                obstruction = obstruction.rotate(rot, expand=True)
                draw.paste(obstruction, (obs_x, obs_y), obstruction)
            card_image = Image.alpha_composite(card_image, draw)

        # adjust brightness to match background
        card_image_gray = card_image.convert("L")
        stat = ImageStat.Stat(card_image_gray)
        card_brightness = stat.mean[0]

        brightness_ratio = bg_brightness / (card_brightness + 1e-5)
        enhancer = ImageEnhance.Brightness(card_image)
        card_image = enhancer.enhance(brightness_ratio)

        # adjust white balance to match background
        # r, g, b, a = card_image.split()
        # r = r.point(lambda i: i * r_ratio)
        # g = g.point(lambda i: i * g_ratio)
        # b = b.point(lambda i: i * b_ratio)
        # card_image = Image.merge('RGBA', (r, g, b, a))

        # change black to transparent in edges
        for y in range(card_image.height):
            for x in range(card_image.width):
                if x < 17 and y < 17 or x > card_image.width - 18 and y < 17 or x < 17 and y > card_image.height - 18 or x > card_image.width - 18 and y > card_image.height - 18:
                    r, g, b, a = card_image.getpixel((x, y))
                    if r == 0 and g == 0 and b == 0:
                        card_image.putpixel((x, y), (0, 0, 0, 0))


        transformed_max_dim = int(math.ceil(math.sqrt(card_image.width**2 + card_image.height**2)))
        # move to center of image
        translate_mat = translate((transformed_max_dim - card_image.width) / 2, (transformed_max_dim - card_image.height) / 2)
        # rotate card
        rotation_mat = rotate(random.uniform(-math.pi/2, math.pi/2), center=(card_image.width / 2, card_image.height / 2))
        # move corners inwards randomly to simulate perspective
        adjust_factor = 0.2
        corner_adjust = perspective_from_corners(
            [
                (0,0), 
                (card_image.width,0), 
                (card_image.width,card_image.height), 
                (0,card_image.height)
            ],
            [
                (random.random()*adjust_factor * card_image.width, random.random()*adjust_factor * card_image.height),
                (card_image.width - (random.random()*adjust_factor * card_image.width), random.random()*adjust_factor * card_image.height),
                (card_image.width - (random.random()*adjust_factor * card_image.width), card_image.height - (random.random()*adjust_factor * card_image.height)),
                (random.random()*adjust_factor * card_image.width, card_image.height - (random.random()*adjust_factor * card_image.height))
            ]
        )

        # compose transformations
        H = compose(
            corner_adjust,
            rotation_mat,
            translate_mat
        )
        H_inv = np.linalg.inv(H)

        # cache starting dimensions
        start_h = card_image.height
        start_w = card_image.width

        # apply perspective transform
        card_image = card_image.transform(
            (transformed_max_dim, transformed_max_dim),
            Image.PERSPECTIVE,
            (to_pillow_perspective(H_inv)),
            resample=Image.BICUBIC,
            fillcolor=(0, 0, 0, 0)
        )

        # apply slight lens distortion
        card_image = mesh_distort(card_image)

        # get transformed corners
        corners = get_corners_after_transform(start_w, start_h, H)

        paste_x = random.randint(0, IMAGE_DIMENSION - max_card_size)
        paste_y = random.randint(0, IMAGE_DIMENSION - max_card_size)

        # position card in grid to avoid overlap
        if not ALLOW_OVERLAP:
            s = math.ceil(math.sqrt(card_amount))
            paste_x = i % math.ceil(math.sqrt(card_amount)) * max_card_size + (random.uniform(-75/s,75/s))
            paste_y = i // math.ceil(math.sqrt(card_amount)) * max_card_size + (random.uniform(-75/s,75/s))
            
            # keep in bounds
            paste_x = max(min(paste_x, IMAGE_DIMENSION - max_card_size), 0)
            paste_y = max(min(paste_y, IMAGE_DIMENSION - max_card_size), 0)

        # paste card onto background
        bg_image.paste(card_image, (int(paste_x), int(paste_y)), card_image)

        # calculate segment shape
        x1 = corners[0][0] + paste_x
        y1 = corners[0][1] + paste_y
        x2 = corners[1][0] + paste_x
        y2 = corners[1][1] + paste_y
        x3 = corners[2][0] + paste_x
        y3 = corners[2][1] + paste_y
        x4 = corners[3][0] + paste_x
        y4 = corners[3][1] + paste_y


        # draw bounding box for debugging
        # draw = ImageDraw.Draw(bg_image)
        # draw.line([(x1, y1), (x2, y2), (x3, y3), (x4, y4), (x1, y1)], fill=(255, 0, 0), width=2)

        shapes.append([x1/IMAGE_DIMENSION, y1/IMAGE_DIMENSION, x2/IMAGE_DIMENSION, y2/IMAGE_DIMENSION, x3/IMAGE_DIMENSION, y3/IMAGE_DIMENSION, x4/IMAGE_DIMENSION, y4/IMAGE_DIMENSION])
    
    return bg_image, shapes

def save_image_and_labels(image: Image.Image, shapes: list[float], index: int, train: bool = True):
    # create directories if they don't exist
    images_path = DATASET_PATH + ("/images/train" if train else "/images/val")
    labels_path = DATASET_PATH + ("/labels/train" if train else "/labels/val")
    os.makedirs(images_path, exist_ok=True)
    os.makedirs(labels_path, exist_ok=True)

    # validate segments are within bounds
    for shape in shapes:
        for num in shape:
            if float(num) < 0 or float(num) > 1:
                print("out of bounds card")
                # return

    # save image
    image_save_path = os.path.join(images_path, f"image_{index:05d}.jpg")
    image.save(image_save_path)

    # save labels
    label_save_path = os.path.join(labels_path, f"image_{index:05d}.txt")
    with open(label_save_path, 'w') as f:
        for shape in shapes:
            f.write("0 " + " ".join(map(str, shape)) + "\n")

reset_index()

for i in tqdm.tqdm(range(AMOUNT_TRAIN), desc="Generating training dataset"):
    img, shapes = create_test_item(i<50)
    save_image_and_labels(img, shapes, i, train=True)

for i in tqdm.tqdm(range(AMOUNT_VAL), desc="Generating validation dataset"):
    img, shapes = create_test_item()
    save_image_and_labels(img, shapes, i, train=False)

yaml_content = f"""
path: {DATASET_PATH}
train: images/train
val: images/val

names:
    0: card
"""

with open(os.path.join(DATASET_PATH, "card_yolo_dataset.yaml"), 'w') as f:
    f.write(yaml_content)
# Out:
# Generating training dataset:   0%|          | 0/250 [00:00<?, ?it/s]C:\Users\rsninja\AppData\Local\Temp\ipykernel_1132\3022227661.py:265: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   distorted_pil = Image.fromarray(rgba, mode="RGBA")
# Generating training dataset:   0%|          | 1/250 [00:00<00:31,  7.83it/s]C:\Users\rsninja\AppData\Local\Temp\ipykernel_1132\2262792262.py:79: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   obstruction.putalpha(Image.fromarray(combined_alpha, mode='L'))
# Generating training dataset:   9%|▉         | 22/250 [00:03<00:31,  7.32it/s]
# out of bounds card
# Generating training dataset: 100%|██████████| 250/250 [00:55<00:00,  4.54it/s]
# Generating validation dataset: 0it [00:00, ?it/s]

# %%
for dirpath, dirnames, filenames in os.walk(DATASET_PATH + ("/images/train")):
    for filename in filenames:
        image_path = filepath = os.path.join(dirpath, filename)
        label_path = os.path.join(DATASET_PATH + "/labels/train", filename.replace(".jpg", ".txt"))

        image = Image.open(image_path).convert("RGB")
        draw = ImageDraw.Draw(image)


        with open(label_path, 'r') as f:
            for line in f:
                parts = line.strip().split()
                class_id = parts[0]
                coords = list(map(float, parts[1:]))

                # Scale coordinates
                x1, y1, x2, y2, x3, y3, x4, y4 = [coord for coord in coords]
                xScale = image.width
                yScale = image.height

                # Draw polygon (bounding box with 4 corners)
                polygon = [(x1 * xScale, y1 * yScale), (x2 * xScale, y2 * yScale), (x3 * xScale, y3 * yScale), (x4 * xScale, y4 * yScale)]
                draw.polygon(polygon, outline="red", width=4)

        # Save image to current directory
        output_path = os.path.join("./test", f"output_{filename}")
        image.save(output_path)

# %% [markdown]
# # Training

# %% [markdown]
# ### model download

# %%
model = YOLO("yolo26n-seg.pt")

# %% [markdown]
# ### model training

# %%
results = model.train(data=os.path.join(DATASET_PATH, "card_yolo_dataset.yaml"), epochs=EPOCHS , imgsz=320, save_period=10, cache=True, max_det=18, patience=20, single_cls=True, overlap_mask=False)

# save model
model.save("card_yolo_best.pt")
# Out:
# New https://pypi.org/project/ultralytics/8.4.33 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.7  Python-3.12.12 torch-2.9.0+cu130 CUDA:0 (NVIDIA GeForce RTX 3060, 12287MiB)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=True, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=../datasets/YOLO_training\card_yolo_dataset.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=320, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=18, mixup=0.0, mode=train, model=yolo26n-seg.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=train12, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=False, patience=20, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=C:\Code\React\CollectiblesApp\src\ai_dev\notebooks\runs\segment\train12, save_frames=False, save_json=False, save_period=10, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=True, source=None, split=val, stream_buffer=False, task=segment, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding class names with single class.
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5, 3, True]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    119808  ultralytics.nn.modules.block.C3k2            [384, 128, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     34304  ultralytics.nn.modules.block.C3k2            [256, 64, 1, True]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     95232  ultralytics.nn.modules.block.C3k2            [192, 128, 1, True]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    463104  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True, 0.5, True]
#  23        [16, 19, 22]  1    790431  ultralytics.nn.modules.head.Segment26        [1, 32, 64, 1, True, [64, 128, 256]]
# YOLO26n-seg summary: 309 layers, 3,053,055 parameters, 3,053,055 gradients, 10.2 GFLOPs
#
# Transferred 844/844 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.10.0 ms, read: 869.6963.2 MB/s, size: 994.3 KB)
# train: Scanning C:\Code\React\CollectiblesApp\src\ai_dev\datasets\YOLO_training\labels\train.cache... 319 images, 1 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 319/319  0.0s
# train: C:\Code\React\CollectiblesApp\src\ai_dev\datasets\YOLO_training\images\train\20260405_164238.jpg: corrupt JPEG restored and saved
# train: C:\Code\React\CollectiblesApp\src\ai_dev\datasets\YOLO_training\images\train\20260405_164245.jpg: corrupt JPEG restored and saved
# train: C:\Code\React\CollectiblesApp\src\ai_dev\datasets\YOLO_training\images\train\20260405_164301.jpg: corrupt JPEG restored and saved
# train: C:\Code\React\CollectiblesApp\src\ai_dev\datasets\YOLO_training\images\train\20260405_164320.jpg: corrupt JPEG restored and saved
# WARNING cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# train: Caching images (0.1GB RAM): 100% ━━━━━━━━━━━━ 319/319 460.2it/s 0.7s0.1s
# val: Fast image access  (ping: 0.10.0 ms, read: 925.21061.7 MB/s, size: 178.1 KB)
# val: Scanning C:\Code\React\CollectiblesApp\src\ai_dev\datasets\YOLO_training\labels\val.cache... 27 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 27/27  0.0s
# WARNING cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# val: Caching images (0.0GB RAM): 100% ━━━━━━━━━━━━ 27/27 752.0it/s 0.0s
# Plotting labels to C:\Code\React\CollectiblesApp\src\ai_dev\notebooks\runs\segment\train12\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: MuSGD(lr=0.002, momentum=0.9) with parameter groups 134 weight(decay=0.0), 154 weight(decay=0.0005), 154 bias(decay=0.0)
# Image sizes 320 train, 320 val
# Using 6 dataloader workers
# Logging results to C:\Code\React\CollectiblesApp\src\ai_dev\notebooks\runs\segment\train12
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       1/100     0.926G      1.125      2.537      3.396     0.0125      5.771        103        320: 100% ━━━━━━━━━━━━ 20/20 2.1it/s 9.7s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.4it/s 0.3s
#                    all         27        140     0.0597      0.207     0.0392     0.0112     0.0329      0.114     0.0204    0.00383
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       2/100     0.996G      1.006      2.095      3.332    0.01059      4.936        129        320: 100% ━━━━━━━━━━━━ 20/20 2.4it/s 8.4s0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.3it/s 0.4s
#                    all         27        140      0.072       0.25     0.0498     0.0149     0.0432       0.15     0.0301    0.00658
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       3/100     0.996G     0.8745      1.583      3.199   0.008743      3.623         97        320: 100% ━━━━━━━━━━━━ 20/20 2.6it/s 7.7s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.1it/s 0.3s
#                    all         27        140     0.0761      0.264     0.0613     0.0227     0.0514      0.179       0.04    0.00977
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       4/100         1G     0.7821      1.256      3.033   0.007528      2.682         83        320: 100% ━━━━━━━━━━━━ 20/20 3.0it/s 6.7s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.3it/s 0.3s
#                    all         27        140      0.117      0.407      0.121     0.0385     0.0576        0.2     0.0522     0.0131
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       5/100      1.03G     0.7389       1.09      2.751   0.006929      2.073         92        320: 100% ━━━━━━━━━━━━ 20/20 3.1it/s 6.5s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.4it/s 0.3s
#                    all         27        140      0.187       0.65      0.371     0.0687     0.0885      0.307     0.0984     0.0166
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       6/100      1.04G     0.6873     0.8612      2.338   0.006106      1.381        113        320: 100% ━━━━━━━━━━━━ 20/20 3.2it/s 6.2s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.4it/s 0.3s
#                    all         27        140      0.467      0.379      0.371     0.0504        0.1        0.2     0.0762     0.0118
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       7/100      1.06G     0.6769     0.8153      1.857   0.006211      1.273         77        320: 100% ━━━━━━━━━━━━ 20/20 3.2it/s 6.2s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.4it/s 0.3s
#                    all         27        140      0.574      0.536      0.497     0.0666      0.148      0.171     0.0701     0.0109
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       8/100      1.07G     0.6506     0.7398      1.669   0.005937      1.059         88        320: 100% ━━━━━━━━━━━━ 20/20 2.9it/s 6.9s0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.0it/s 0.3s
#                    all         27        140      0.503      0.614      0.545     0.0736      0.154      0.207     0.0795     0.0121
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       9/100      1.09G      0.634     0.6699      1.484   0.005712     0.8143         80        320: 100% ━━━━━━━━━━━━ 20/20 2.9it/s 7.0s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.1it/s 0.3s
#                    all         27        140      0.615      0.571      0.555      0.073      0.157      0.233     0.0798     0.0122
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      10/100      1.09G     0.6376     0.7199      1.325   0.005594     0.8685        116        320: 100% ━━━━━━━━━━━━ 20/20 3.0it/s 6.6s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.3it/s 0.3s
#                    all         27        140      0.485        0.5      0.393     0.0529      0.119       0.25      0.075     0.0128
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      11/100      1.09G     0.6274     0.6787      1.261   0.005566     0.8256         76        320: 100% ━━━━━━━━━━━━ 20/20 3.2it/s 6.2s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.4it/s 0.3s
#                    all         27        140      0.587      0.614      0.558     0.0772       0.15      0.243     0.0815     0.0148
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      12/100      1.09G     0.6203     0.6381      1.166   0.005558      0.693        118        320: 100% ━━━━━━━━━━━━ 20/20 3.1it/s 6.4s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.2it/s 0.3s
#                    all         27        140      0.532      0.593      0.411     0.0569      0.201       0.25     0.0884     0.0142
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      13/100      1.09G     0.5943     0.6395      1.056   0.005315     0.6302        103        320: 100% ━━━━━━━━━━━━ 20/20 3.2it/s 6.3s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.4it/s 0.3s
#                    all         27        140      0.592       0.65      0.549     0.0756      0.254      0.279      0.111     0.0162
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      14/100      1.09G     0.6184     0.6448      1.012   0.005356     0.6174         83        320: 100% ━━━━━━━━━━━━ 20/20 3.2it/s 6.3s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.8it/s 0.4s
#                    all         27        140       0.64      0.643      0.566     0.0759      0.264      0.264       0.11      0.016
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      15/100      1.09G      0.608     0.6504     0.9707   0.005308     0.6383         84        320: 100% ━━━━━━━━━━━━ 20/20 3.1it/s 6.4s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.4it/s 0.3s
#                    all         27        140      0.639      0.664      0.557     0.0744      0.272      0.264      0.114     0.0167
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      16/100      1.09G     0.5858     0.6417       0.91   0.005027     0.6627        108        320: 100% ━━━━━━━━━━━━ 20/20 3.2it/s 6.3s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.3it/s 0.3s
#                    all         27        140      0.689      0.707      0.622     0.0851      0.269      0.286      0.113     0.0171
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      17/100      1.09G     0.5629     0.6269     0.8484   0.004911     0.4877        103        320: 100% ━━━━━━━━━━━━ 20/20 3.0it/s 6.7s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.2it/s 0.3s
#                    all         27        140      0.707      0.764      0.665     0.0915       0.26        0.3      0.116     0.0175
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      18/100      1.09G     0.5573     0.5923     0.8357   0.004932     0.4994         94        320: 100% ━━━━━━━━━━━━ 20/20 2.8it/s 7.1s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.7it/s 0.4s
#                    all         27        140      0.669      0.722      0.611      0.085      0.267      0.286      0.117     0.0175
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      19/100      1.09G      0.586     0.6082     0.7959   0.005095     0.4446        117        320: 100% ━━━━━━━━━━━━ 20/20 2.7it/s 7.5s0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.6it/s 0.4s
#                    all         27        140      0.786      0.707      0.687     0.0927      0.279      0.286      0.126     0.0181
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      20/100      1.09G     0.5612     0.5808     0.7527   0.004902     0.4365         99        320: 100% ━━━━━━━━━━━━ 20/20 2.3it/s 8.9s0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.7it/s 0.4s
#                    all         27        140      0.749      0.814       0.75      0.105       0.27      0.293      0.119      0.017
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      21/100      1.09G     0.5541     0.5501     0.7906   0.004891      0.419        115        320: 100% ━━━━━━━━━━━━ 20/20 2.9it/s 7.0s0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.5it/s 0.4s
#                    all         27        140      0.724      0.693      0.611     0.0826      0.263      0.279      0.117     0.0169
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      22/100      1.09G     0.5627       0.61     0.7394   0.004729     0.4124         85        320: 100% ━━━━━━━━━━━━ 20/20 2.6it/s 7.6s0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.2it/s 0.3s
#                    all         27        140       0.71       0.75      0.631     0.0861      0.276      0.271      0.121     0.0174
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      23/100      1.09G     0.5248     0.5318     0.6537   0.004572     0.4858         90        320: 100% ━━━━━━━━━━━━ 20/20 3.0it/s 6.7s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.0it/s 0.3s
#                    all         27        140      0.712      0.693      0.605     0.0802      0.265      0.279      0.114     0.0172
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      24/100      1.09G     0.5603     0.5494     0.6676   0.004733     0.3894         83        320: 100% ━━━━━━━━━━━━ 20/20 3.0it/s 6.6s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.8it/s 0.4s
#                    all         27        140      0.758      0.779      0.715     0.0968      0.271      0.279      0.116     0.0174
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      25/100      1.09G     0.5478      0.545     0.6723   0.004768     0.4031         85        320: 100% ━━━━━━━━━━━━ 20/20 2.8it/s 7.3s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.1it/s 0.3s
#                    all         27        140       0.72      0.757      0.671     0.0924      0.295      0.314      0.136     0.0204
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      26/100      1.09G     0.5764      0.553     0.6356   0.004765     0.3617        106        320: 100% ━━━━━━━━━━━━ 20/20 2.7it/s 7.3s0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.9it/s 0.3s
#                    all         27        140      0.744      0.743      0.652     0.0839      0.291      0.307      0.134     0.0195
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      27/100      1.09G     0.5521     0.5599     0.6108   0.004696     0.3469         98        320: 100% ━━━━━━━━━━━━ 20/20 2.8it/s 7.0s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.2it/s 0.3s
#                    all         27        140      0.728      0.786      0.676     0.0952      0.304      0.307      0.144     0.0219
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      28/100      1.09G      0.541     0.5526     0.6266   0.004553     0.3246         99        320: 100% ━━━━━━━━━━━━ 20/20 2.7it/s 7.3s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.2it/s 0.3s
#                    all         27        140      0.755      0.729      0.667     0.0912      0.282        0.3      0.131       0.02
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      29/100      1.09G     0.5291     0.5256     0.5979   0.004666     0.4368        108        320: 100% ━━━━━━━━━━━━ 20/20 2.9it/s 6.9s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.4it/s 0.3s
#                    all         27        140      0.797      0.714      0.683     0.0924      0.285      0.293      0.129     0.0194
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      30/100      1.09G     0.5262     0.5268     0.5922   0.004634     0.4544         95        320: 100% ━━━━━━━━━━━━ 20/20 3.1it/s 6.5s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.3it/s 0.3s
#                    all         27        140      0.806      0.814      0.785       0.11      0.298      0.329      0.143     0.0206
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      31/100      1.09G      0.515     0.5006     0.5705   0.004619     0.3551         74        320: 100% ━━━━━━━━━━━━ 20/20 3.1it/s 6.4s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.3it/s 0.3s
#                    all         27        140      0.772      0.807      0.746      0.103      0.299      0.314      0.136       0.02
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      32/100      1.09G     0.5385     0.5359     0.5454   0.004631     0.3213        104        320: 100% ━━━━━━━━━━━━ 20/20 2.7it/s 7.3s0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.8it/s 0.4s
#                    all         27        140      0.771      0.793      0.719     0.0975      0.307      0.321      0.141     0.0202
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      33/100      1.09G     0.5579     0.5404     0.5597   0.004676     0.3396        107        320: 100% ━━━━━━━━━━━━ 20/20 2.5it/s 7.9s0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.6it/s 0.4s
#                    all         27        140      0.818        0.8      0.734      0.104      0.273      0.293      0.118     0.0175
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      34/100      1.09G     0.5278     0.5018     0.5277   0.004434     0.2918         77        320: 100% ━━━━━━━━━━━━ 20/20 2.8it/s 7.2s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.3it/s 0.3s
#                    all         27        140      0.769      0.793      0.698     0.0954      0.265      0.279      0.114     0.0169
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      35/100      1.09G     0.5206     0.5185      0.547    0.00442     0.2798         92        320: 100% ━━━━━━━━━━━━ 20/20 3.2it/s 6.3s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.4it/s 0.3s
#                    all         27        140      0.696      0.729      0.615     0.0847      0.287        0.3      0.127      0.019
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      36/100      1.09G     0.5136     0.5162     0.4983   0.004494     0.3461         98        320: 100% ━━━━━━━━━━━━ 20/20 3.2it/s 6.3s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.0it/s 0.3s
#                    all         27        140      0.688        0.7      0.606     0.0845      0.294        0.3      0.133     0.0202
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      37/100      1.09G      0.513     0.5174     0.5079   0.004418      0.348         74        320: 100% ━━━━━━━━━━━━ 20/20 2.7it/s 7.4s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.3it/s 0.3s
#                    all         27        140      0.767      0.729      0.674      0.096      0.308      0.293      0.144     0.0221
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      38/100      1.09G     0.5307     0.4843     0.5121   0.004455     0.4361         82        320: 100% ━━━━━━━━━━━━ 20/20 2.9it/s 6.8s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.0it/s 0.3s
#                    all         27        140      0.812        0.8      0.753      0.109      0.286      0.279      0.132     0.0215
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      39/100      1.09G     0.5305     0.4778      0.493   0.004506      0.327         73        320: 100% ━━━━━━━━━━━━ 20/20 3.0it/s 6.8s0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.0it/s 0.3s
#                    all         27        140      0.785       0.75      0.701        0.1      0.297      0.279      0.133     0.0208
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      40/100      1.09G     0.5358     0.4946     0.4988   0.004705      0.272         78        320: 100% ━━━━━━━━━━━━ 20/20 2.8it/s 7.1s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.2it/s 0.3s
#                    all         27        140      0.818      0.768      0.719      0.103      0.281      0.296      0.136     0.0209
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      41/100      1.09G     0.5013     0.5081     0.5074   0.004416     0.3512        114        320: 100% ━━━━━━━━━━━━ 20/20 3.0it/s 6.7s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.1it/s 0.3s
#                    all         27        140        0.8      0.802      0.735       0.11      0.327        0.3      0.151     0.0257
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      42/100      1.09G     0.5185     0.5102     0.5105   0.004499     0.3524         61        320: 100% ━━━━━━━━━━━━ 20/20 3.0it/s 6.8s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.2it/s 0.3s
#                    all         27        140      0.785      0.779      0.695      0.106      0.308        0.3      0.142     0.0275
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      43/100      1.09G      0.508     0.5015     0.4692   0.004321     0.2966         96        320: 100% ━━━━━━━━━━━━ 20/20 3.1it/s 6.5s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.3it/s 0.3s
#                    all         27        140      0.807      0.776      0.705      0.106      0.272        0.3      0.124       0.02
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      44/100      1.09G     0.5181     0.5188      0.476   0.004232     0.3441         81        320: 100% ━━━━━━━━━━━━ 20/20 3.1it/s 6.4s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.4it/s 0.3s
#                    all         27        140      0.811      0.771      0.713      0.104        0.3      0.286      0.143     0.0248
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      45/100      1.09G      0.508     0.4856     0.4297   0.004356       0.32        112        320: 100% ━━━━━━━━━━━━ 20/20 3.2it/s 6.3s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.8it/s 0.4s
#                    all         27        140      0.756       0.73      0.666     0.0966       0.27        0.3      0.145     0.0229
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      46/100      1.09G     0.5074     0.4915     0.4546    0.00442     0.2619         88        320: 100% ━━━━━━━━━━━━ 20/20 3.1it/s 6.5s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.2it/s 0.3s
#                    all         27        140      0.731       0.75      0.646       0.09      0.303      0.279      0.135     0.0204
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      47/100      1.09G       0.52     0.5096     0.4504   0.004453     0.2663         83        320: 100% ━━━━━━━━━━━━ 20/20 3.2it/s 6.3s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.4it/s 0.3s
#                    all         27        140      0.819      0.806       0.71      0.104       0.29        0.3      0.131     0.0198
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      48/100      1.09G     0.5254      0.484     0.4283   0.004412     0.2618         99        320: 100% ━━━━━━━━━━━━ 20/20 3.2it/s 6.3s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.2it/s 0.3s
#                    all         27        140      0.792        0.8      0.711      0.106      0.281      0.271      0.124     0.0196
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      49/100      1.09G     0.5069     0.4729     0.4367   0.004311     0.2403         85        320: 100% ━━━━━━━━━━━━ 20/20 3.2it/s 6.2s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.3it/s 0.3s
#                    all         27        140      0.819        0.8      0.727      0.108      0.276      0.279       0.12     0.0195
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      50/100      1.09G     0.5248     0.5137     0.4409   0.004367     0.2893         77        320: 100% ━━━━━━━━━━━━ 20/20 3.2it/s 6.3s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.9it/s 0.3s
#                    all         27        140      0.788       0.77       0.67     0.0998      0.282      0.279      0.121     0.0192
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      51/100      1.09G       0.52     0.5106     0.4251   0.004438     0.2835         95        320: 100% ━━━━━━━━━━━━ 20/20 3.2it/s 6.3s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.3it/s 0.3s
#                    all         27        140      0.736      0.729      0.606     0.0857      0.282      0.279      0.113     0.0185
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      52/100      1.09G     0.4988     0.4917     0.4141   0.004247     0.3197         74        320: 100% ━━━━━━━━━━━━ 20/20 3.1it/s 6.4s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.6it/s 0.3s
#                    all         27        140       0.81      0.807      0.734      0.112      0.285      0.286      0.124     0.0186
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      53/100      1.09G     0.4854     0.4747      0.418    0.00417     0.2756         69        320: 100% ━━━━━━━━━━━━ 20/20 3.1it/s 6.4s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.4it/s 0.3s
#                    all         27        140      0.785      0.784       0.69        0.1      0.311      0.293      0.135     0.0193
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      54/100      1.09G     0.4972     0.4866     0.4108   0.004186     0.2408         93        320: 100% ━━━━━━━━━━━━ 20/20 3.2it/s 6.3s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.5it/s 0.3s
#                    all         27        140      0.779      0.764       0.67      0.097       0.32      0.314      0.143     0.0203
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      55/100      1.09G     0.4891     0.4721     0.4147   0.004189     0.2364         75        320: 100% ━━━━━━━━━━━━ 20/20 2.9it/s 6.9s0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.1it/s 0.3s
#                    all         27        140      0.668      0.671      0.547     0.0768      0.298      0.307      0.137     0.0201
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      56/100      1.09G      0.501     0.4939     0.4056    0.00418     0.2381         85        320: 100% ━━━━━━━━━━━━ 20/20 2.8it/s 7.1s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.3it/s 0.3s
#                    all         27        140      0.758       0.75      0.645     0.0903      0.294        0.3      0.124     0.0185
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      57/100      1.09G      0.502     0.4808     0.4136   0.004284     0.3024         79        320: 100% ━━━━━━━━━━━━ 20/20 3.0it/s 6.6s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.1it/s 0.3s
#                    all         27        140      0.758      0.759      0.652     0.0987      0.317      0.321      0.154     0.0275
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      58/100      1.09G     0.5047     0.4996     0.4087    0.00421     0.2321         72        320: 100% ━━━━━━━━━━━━ 20/20 3.0it/s 6.6s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.1it/s 0.3s
#                    all         27        140      0.759       0.75      0.654     0.0971      0.317      0.307      0.155     0.0269
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      59/100      1.09G     0.4848     0.4753        0.4    0.00405     0.2716         64        320: 100% ━━━━━━━━━━━━ 20/20 3.1it/s 6.4s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.2it/s 0.3s
#                    all         27        140      0.734      0.729      0.638     0.0992      0.275      0.293      0.142     0.0273
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      60/100      1.09G     0.4963      0.468     0.3874   0.004125     0.3837        100        320: 100% ━━━━━━━━━━━━ 20/20 3.1it/s 6.4s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.3it/s 0.3s
#                    all         27        140      0.664      0.679      0.568     0.0864       0.28      0.286      0.139     0.0261
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      61/100      1.09G     0.5151     0.4788     0.3686   0.004187     0.2301        102        320: 100% ━━━━━━━━━━━━ 20/20 3.1it/s 6.4s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.2it/s 0.3s
#                    all         27        140      0.753      0.771      0.667      0.103      0.307      0.314      0.154     0.0269
# EarlyStopping: Training stopped early as no improvement observed in last 20 epochs. Best results observed at epoch 41, best model saved as best.pt.
# To update EarlyStopping(patience=20) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 61 epochs completed in 0.131 hours.
# Optimizer stripped from C:\Code\React\CollectiblesApp\src\ai_dev\notebooks\runs\segment\train12\weights\last.pt, 6.5MB
# Optimizer stripped from C:\Code\React\CollectiblesApp\src\ai_dev\notebooks\runs\segment\train12\weights\best.pt, 6.5MB
#
# Validating C:\Code\React\CollectiblesApp\src\ai_dev\notebooks\runs\segment\train12\weights\best.pt...
# Ultralytics 8.4.7  Python-3.12.12 torch-2.9.0+cu130 CUDA:0 (NVIDIA GeForce RTX 3060, 12287MiB)
# YOLO26n-seg summary (fused): 139 layers, 2,689,079 parameters, 0 gradients, 9.0 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.0it/s 0.3s
#                    all         27        140        0.8      0.802      0.732      0.112      0.327        0.3      0.152     0.0278
# Speed: 0.1ms preprocess, 1.4ms inference, 0.0ms loss, 1.1ms postprocess per image
# Results saved to C:\Code\React\CollectiblesApp\src\ai_dev\notebooks\runs\segment\train12

# %% [markdown]
# ### model testing

# %%
model = YOLO("./card_yolo_best.pt")

metrics = model.val(data=os.path.join(DATASET_PATH, "card_yolo_dataset.yaml"), imgsz=320, max_det=18, single_cls=True, overlap_mask=False)

metrics.box.map  # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps  # a list containing mAP50-95 for each category
# Out:
# Ultralytics 8.4.7  Python-3.12.12 torch-2.9.0+cu130 CUDA:0 (NVIDIA GeForce RTX 3060, 12287MiB)
# YOLO26n-seg summary (fused): 139 layers, 2,689,079 parameters, 0 gradients, 9.0 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 642.492.7 MB/s, size: 68.8 KB)
# val: Scanning C:\Code\React\CollectiblesApp\src\ai_dev\datasets\YOLO_training\labels\val.cache... 27 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 27/27  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.9s/it 3.8s<11.1s
#                    all         27        140      0.801        0.8      0.728      0.109      0.327        0.3      0.151     0.0254
# Speed: 1.0ms preprocess, 3.0ms inference, 0.0ms loss, 1.6ms postprocess per image
# Results saved to C:\Code\React\CollectiblesApp\src\ai_dev\notebooks\runs\segment\val7
# array([    0.10896])

# %% [markdown]
# ### model exporting

# %%
model = YOLO("./card_yolo_best.pt")

model.export(format="onnx", opset=17, dynamic=False, imgsz=320, simplify=True)
# Out:
# Ultralytics 8.4.7  Python-3.12.12 torch-2.9.0+cu130 CPU (Intel Core i5-9600K 3.70GHz)
# YOLO26n-seg summary (fused): 139 layers, 2,689,079 parameters, 0 gradients, 9.0 GFLOPs
#
# PyTorch: starting from 'card_yolo_best.pt' with input shape (1, 3, 320, 320) BCHW and output shape(s) ((1, 300, 38), (1, 32, 80, 80)) (6.2 MB)
#
# ONNX: starting export with onnx 1.20.1 opset 17...
# c:\ProgramData\miniconda3\envs\cudaenv\Lib\site-packages\torch\onnx\_internal\torchscript_exporter\symbolic_opset9.py:5353: UserWarning: Exporting aten::index operator of advanced indexing in opset 17 is achieved by combination of multiple ONNX operators, including Reshape, Transpose, Concat, and Gather. If indices include negative values, the exported graph will produce incorrect results.
#   warnings.warn(
# ONNX: slimming with onnxslim 0.1.82...
# ONNX: export success  2.4s, saved as 'card_yolo_best.onnx' (10.4 MB)
#
# Export complete (2.8s)
# Results saved to C:\Code\React\CollectiblesApp\src\ai_dev\notebooks
# Predict:         yolo predict task=segment model=card_yolo_best.onnx imgsz=320
# Validate:        yolo val task=segment model=card_yolo_best.onnx imgsz=320 data=../datasets/YOLO_training\card_yolo_dataset.yaml
# Visualize:       https://netron.app
# 'card_yolo_best.onnx'
